# %% [markdown]
# <a href="https://colab.research.google.com/github/krishaaaaa123/Image-Processing-/blob/main/project6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Getting The Image

# %%
# !wget 'https://www.daysoftheyear.com/wp-content/uploads/puppy-day-e1574071869348.jpg'
# Out:
# --2023-07-19 08:04:46--  https://www.daysoftheyear.com/wp-content/uploads/puppy-day-e1574071869348.jpg
# Resolving www.daysoftheyear.com (www.daysoftheyear.com)... 172.66.40.137, 172.66.43.119, 2606:4700:3108::ac42:2889, ...
# Connecting to www.daysoftheyear.com (www.daysoftheyear.com)|172.66.40.137|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69382 (68K) [image/jpeg]
# Saving to: ‘puppy-day-e1574071869348.jpg’
#
# puppy-day-e15740718 100%[===================>]  67.76K  --.-KB/s    in 0.005s
#
# 2023-07-19 08:04:46 (13.3 MB/s) - ‘puppy-day-e1574071869348.jpg’ saved [69382/69382]

# %%
#Importing the Libraries

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('/content/puppy-day-e1574071869348.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (900, 1990, 3)

# %%
print(img)
# Out:
# [[[191 198 208]
#   [191 198 208]
#   [191 198 208]
#   ...
#   [ 77  65  25]
#   [ 77  65  25]
#   [ 77  65  25]]
#
#  [[191 198 208]
#   [191 198 208]
#   [191 198 208]
#   ...
#   [ 77  65  25]
#   [ 77  65  25]
#   [ 77  65  25]]
#
#  [[191 198 208]
#   [191 198 208]
#   [191 198 208]
#   ...
#   [ 78  66  26]
#   [ 78  66  26]
#   [ 78  66  26]]
#
#  ...
#
#  [[146 136  83]
#   [146 136  83]
#   [146 136  83]
#   ...
#   [144 137  83]
#   [144 137  83]
#   [144 137  83]]
#
#  [[146 136  83]
#   [146 136  83]
#   [146 136  83]
#   ...
#   [144 137  83]
#   [144 137  83]
#   [144 137  83]]
#
#  [[146 136  83]
#   [146 136  83]
#   [146 136  83]
#   ...
#   [144 137  83]
#   [144 137  83]
#   [144 137  83]]]

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# RESIZING THE IMAGE

# %%
from PIL import Image

# %%
img = Image.open('/content/puppy-day-e1574071869348.jpg')
img_resized = img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
img_res = mpimg.imread('/content/dog_image_resized.jpg')
# displaying the image from numpy array

img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# Converting to Grayscale image

# %%
import cv2

# %%
img = cv2.imread('/content/puppy-day-e1574071869348.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
print(grayscale_image)
# Out:
# [[200 200 200 ...  54  54  54]
#  [200 200 200 ...  54  54  54]
#  [200 200 200 ...  55  55  55]
#  ...
#  [121 121 121 ... 122 122 122]
#  [121 121 121 ... 122 122 122]
#  [121 121 121 ... 122 122 122]]

# %%
grayscale_image.shape
# Out:
# (900, 1990)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=1990x900 at 0x7ABF6CCC0AF0>

# %%
#saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
